# %%
# !git clone https://github.com/PercastreMarco/An-lisis-Formula-1-World-Championship-1950---2024-.git
# Out:
# Cloning into 'An-lisis-Formula-1-World-Championship-1950---2024-'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 13 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 6.47 KiB | 6.47 MiB/s, done.

# %%
# %cd An-lisis-Formula-1-World-Championship-1950---2024-
# Out:
# /content/An-lisis-Formula-1-World-Championship-1950---2024-

# %%
# !ls datasets
# Out:
# ls: cannot access 'datasets': No such file or directory

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rohanrao/formula-1-world-championship-1950-2020")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/rohanrao/formula-1-world-championship-1950-2020/versions/24
